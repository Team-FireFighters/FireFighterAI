# %%
HOME = "/Users/rishit/Documents/VIT/SEM5_point_5/EPICS"
print(HOME)
# Out:
# /Users/rishit/Documents/VIT/SEM5_point_5/EPICS

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.16 torch-2.1.1 CPU
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 208.0/228.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet


from roboflow import Roboflow
rf = Roboflow(api_key="hYOGvyN7x7PYrSkLS6U0")
project = rf.workspace("custom-thxhn").project("fire-wrpgm")
dataset = project.version(8).download("yolov8")
# Out:
# mkdir: /Users/rishit/Documents/VIT/SEM5_point_5/EPICS/datasets: File exists
# /Users/rishit/Documents/VIT/SEM5_point_5/EPICS/datasets
# WARNING: Ignoring invalid distribution -orch (/Users/rishit/miniforge3/envs/mlp/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -orch (/Users/rishit/miniforge3/envs/mlp/lib/python3.8/site-packages)
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to fire-8 in yolov8:: 100%|██████████| 1970/1970 [00:00<00:00, 7394.31it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /Users/rishit/Documents/VIT/SEM5_point_5/EPICS
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:02<00:00, 7.76MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.16 torch-2.1.1 CPU
# ...

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("/Users/rishit/Documents/VIT/SEM5_point_5/EPICS/best.pt")

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class names
            cls = int(box.cls[0])
        
            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.16 torch-2.1.1 CPU
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# Confidence ---> 0.64
# Confidence ---> 0.64
# Confidence ---> 0.67
# Confidence ---> 0.66
# Confidence ---> 0.58
# Confidence ---> 0.61
# Confidence ---> 0.55
# Confidence ---> 0.26
# Confidence ---> 0.6
# Confidence ---> 0.58
# Confidence ---> 0.65
# Confidence ---> 0.61
# Confidence ---> 0.65
# Confidence ---> 0.55
# Confidence ---> 0.66
# Confidence ---> 0.59
# Confidence ---> 0.61
# Confidence ---> 0.57
# Confidence ---> 0.57
# Confidence ---> 0.34
# Confidence ---> 0.6
# Confidence ---> 0.63
# Confidence ---> 0.62
# Confidence ---> 0.31
# Confidence ---> 0.6
# Confidence ---> 0.63
# Confidence ---> 0.36
# Confidence ---> 0.61
# Confidence ---> 0.62
# Confidence ---> 0.64
# Confidence ---> 0.28
# Confidence ---> 0.59
# Confidence ---> 0.34
# Confidence ---> 0.64
# Confidence ---> 0.64
# Confidence ---> 0.27
# Confidence ---> 0.63
# ...

# %%
cv2.destroyAllWindows()

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/Users/rishit/Documents/VIT/SEM5_point_5/EPICS/best.pt conf=0.25 source=/Users/rishit/Documents/VIT/SEM5_point_5/EPICS/forestfire.mp4 save=True
# Out:
# /Users/rishit/Documents/VIT/SEM5_point_5/EPICS
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/Users/rishit/Library/Application Support/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics YOLOv8.2.2 🚀 Python-3.11.7 torch-2.2.0 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/901) /Users/rishit/Documents/VIT/SEM5_point_5/EPICS/forestfire.mp4: 800x480 1 Fire, 187.4ms
# video 1/1 (frame 2/901) /Users/rishit/Documents/VIT/SEM5_point_5/EPICS/forestfire.mp4: 800x480 1 Fire, 168.8ms
# video 1/1 (frame 3/901) /Users/rishit/Documents/VIT/SEM5_point_5/EPICS/forestfire.mp4: 800x480 1 Fire, 160.6ms
# ...
